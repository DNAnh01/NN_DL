# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('./dataset/X_train.npy', allow_pickle=True)
y_train = np.load('./dataset/y_train.npy', allow_pickle=True)
X_test = np.load('./dataset/X_test.npy', allow_pickle=True)
y_test = np.load('./dataset/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255

print(X_train.shape)
# Out:
# (60000, 784)

# %%
batch_size = 512
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(10, activation='softmax', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

# declare optimization method and loss function
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# 118/118 [==============================] - 1s 7ms/step - loss: 0.3973 - accuracy: 0.8936
# Epoch 42/50
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3954 - accuracy: 0.8942
# Epoch 43/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.3934 - accuracy: 0.8945
# Epoch 44/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.3916 - accuracy: 0.8950
# Epoch 45/50
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3898 - accuracy: 0.8953
# Epoch 46/50
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3881 - accuracy: 0.8957
# Epoch 47/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.3864 - accuracy: 0.8959
# Epoch 48/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.3848 - accuracy: 0.8965
# Epoch 49/50
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3833 - accuracy: 0.8966
# Epoch 50/50
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3818 - accuracy: 0.8970
#
#
# Test accuracy: 0.9034

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.xlabel('iteration')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# MLP - sigmoid

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('./dataset/X_train.npy', allow_pickle=True)
y_train = np.load('./dataset/y_train.npy', allow_pickle=True)
X_test = np.load('./dataset/X_test.npy', allow_pickle=True)
y_test = np.load('./dataset/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 512
epochs = 50

# create model
model = tf.keras.Sequential()

model.add(tf.keras.Input(shape=(784,)))

model.add(tf.keras.layers.Dense(128, activation='sigmoid', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

model.add(tf.keras.layers.Dense(10, activation='softmax', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

# declare optimization method and loss function
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# 118/118 [==============================] - 2s 15ms/step - loss: 0.8611 - accuracy: 0.7939
# Epoch 42/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.8401 - accuracy: 0.7983
# Epoch 43/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.8204 - accuracy: 0.8022
# Epoch 44/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.8018 - accuracy: 0.8065
# Epoch 45/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.7842 - accuracy: 0.8103
# Epoch 46/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.7677 - accuracy: 0.8131
# Epoch 47/50
# 118/118 [==============================] - 2s 20ms/step - loss: 0.7521 - accuracy: 0.8164
# Epoch 48/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.7373 - accuracy: 0.8196
# Epoch 49/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.7232 - accuracy: 0.8223
# Epoch 50/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.7100 - accuracy: 0.8254
#
#
# Test accuracy: 0.8297

# %%
# MLP - relu

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('./dataset/X_train.npy', allow_pickle=True)
y_train = np.load('./dataset/y_train.npy', allow_pickle=True)
X_test = np.load('./dataset/X_test.npy', allow_pickle=True)
y_test = np.load('./dataset/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 1024
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# declare optimization method and loss function
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# 59/59 [==============================] - 2s 28ms/step - loss: 0.3421 - accuracy: 0.9046
# Epoch 43/50
# 59/59 [==============================] - 2s 26ms/step - loss: 0.3398 - accuracy: 0.9054
# Epoch 44/50
# 59/59 [==============================] - 1s 24ms/step - loss: 0.3375 - accuracy: 0.9059
# Epoch 45/50
# 59/59 [==============================] - 1s 25ms/step - loss: 0.3353 - accuracy: 0.9065
# Epoch 46/50
# 59/59 [==============================] - 2s 26ms/step - loss: 0.3332 - accuracy: 0.9069
# Epoch 47/50
# 59/59 [==============================] - 2s 26ms/step - loss: 0.3311 - accuracy: 0.9074
# Epoch 48/50
# 59/59 [==============================] - 2s 28ms/step - loss: 0.3291 - accuracy: 0.9078
# Epoch 49/50
# 59/59 [==============================] - 2s 27ms/step - loss: 0.3272 - accuracy: 0.9087
# Epoch 50/50
# 59/59 [==============================] - 1s 25ms/step - loss: 0.3253 - accuracy: 0.9091
#
#
# Test accuracy: 0.9125

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# adam

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('./dataset/X_train.npy', allow_pickle=True)
y_train = np.load('./dataset/y_train.npy', allow_pickle=True)
X_test = np.load('./dataset/X_test.npy', allow_pickle=True)
y_test = np.load('./dataset/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 512
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(128, activation='relu', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))
model.add(tf.keras.layers.Dense(10, activation='softmax', 
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                               bias_initializer=keras.initializers.Zeros()))

# declare optimization method and loss function
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0094 - accuracy: 0.9989
# Epoch 41/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0087 - accuracy: 0.9989
# Epoch 42/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0080 - accuracy: 0.9991
# Epoch 43/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0076 - accuracy: 0.9992
# Epoch 44/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0069 - accuracy: 0.9993
# Epoch 45/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0063 - accuracy: 0.9996
# Epoch 46/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0057 - accuracy: 0.9996
# Epoch 47/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0056 - accuracy: 0.9996
# Epoch 48/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0048 - accuracy: 0.9997
# Epoch 49/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0045 - accuracy: 0.9998
# Epoch 50/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0042 - accuracy: 0.9999
#
#
# Test accuracy: 0.9787

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# softmax

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
tf.keras.backend.set_floatx('float64')

# Data Preparation
X_train = np.load('./dataset/X_train.npy', allow_pickle=True)
y_train = np.load('./dataset/y_train.npy', allow_pickle=True)
X_test = np.load('./dataset/X_test.npy', allow_pickle=True)
y_test = np.load('./dataset/y_test.npy', allow_pickle=True)

X_train = X_train/255
X_test  = X_test/255


batch_size = 1024
epochs = 50

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(784,)))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# declare optimization method and loss function
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# training
history = model.fit(X_train, y_train, batch_size, epochs)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\n\nTest accuracy:', test_acc)
# Out:
# 59/59 [==============================] - 1s 12ms/step - loss: 0.2576 - accuracy: 0.9286
# Epoch 44/50
# 59/59 [==============================] - 1s 15ms/step - loss: 0.2568 - accuracy: 0.9290
# Epoch 45/50
# 59/59 [==============================] - 1s 14ms/step - loss: 0.2560 - accuracy: 0.9296
# Epoch 46/50
# 59/59 [==============================] - 1s 10ms/step - loss: 0.2551 - accuracy: 0.9295
# Epoch 47/50
# 59/59 [==============================] - 1s 11ms/step - loss: 0.2547 - accuracy: 0.9298
# Epoch 48/50
# 59/59 [==============================] - 1s 10ms/step - loss: 0.2538 - accuracy: 0.9295
# Epoch 49/50
# 59/59 [==============================] - 1s 11ms/step - loss: 0.2533 - accuracy: 0.9300
# Epoch 50/50
# 59/59 [==============================] - 1s 11ms/step - loss: 0.2524 - accuracy: 0.9302
#
#
# Test accuracy: 0.9259

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
